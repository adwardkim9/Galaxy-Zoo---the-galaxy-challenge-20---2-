# %%
import pandas as pd
import numpy as np

# %%
model_1 = pd.read_csv('Output_201119.csv')
model_2 = pd.read_csv('Output_201120(resnet).csv')

# %%
model_1.head(10)
# Out:
#    GalaxyID  Class1.1  Class1.2  ...  Class11.4  Class11.5  Class11.6
# 0    100018  0.504672  0.485025  ...   0.001927   0.003831   0.094999
# 1    100037  0.530359  0.457630  ...   0.000179   0.000520   0.014087
# 2    100042  0.727551  0.276068  ...   0.000066   0.000577   0.019516
# 3    100052  0.618991  0.341121  ...   0.000818   0.002336   0.025307
# 4    100056  0.390457  0.592301  ...   0.000100   0.000306   0.005773
# 5    100058  0.277898  0.692474  ...   0.014775   0.012724   0.168075
# 6    100062  0.271200  0.716636  ...   0.009455   0.008861   0.194378
# 7    100065  0.521225  0.448694  ...   0.000506   0.002132   0.035660
# 8    100071  0.030119  0.959877  ...   0.004006   0.001648   0.028964
# 9    100076  0.306130  0.652687  ...   0.006276   0.006525   0.117064
#
# [10 rows x 38 columns]

# %%
model_2.head(10)
# Out:
#    GalaxyID  Class1.1  Class1.2  ...  Class11.4  Class11.5  Class11.6
# 0    100018  0.406169  0.583853  ...   0.001331   0.002051   0.101244
# 1    100037  0.494883  0.489447  ...   0.000135   0.000117   0.020378
# 2    100042  0.683549  0.300092  ...   0.000068   0.000086   0.020151
# 3    100052  0.576874  0.407519  ...   0.002520   0.006226   0.046942
# 4    100056  0.338166  0.657677  ...   0.000276   0.000200   0.006717
# 5    100058  0.230844  0.733588  ...   0.013656   0.009458   0.136396
# 6    100062  0.262962  0.717855  ...   0.006996   0.008502   0.207930
# 7    100065  0.535272  0.411696  ...   0.000203   0.000571   0.020978
# 8    100071  0.088613  0.886256  ...   0.003756   0.001964   0.051996
# 9    100076  0.214284  0.753611  ...   0.004689   0.003844   0.145513
#
# [10 rows x 38 columns]

# %%
df_concat = pd.concat((model_1, model_2))

# %%
by_row_index = df_concat.groupby(df_concat.index)
df_means = by_row_index.mean()

# %%
df_means.head(10)
# Out:
#    GalaxyID  Class1.1  Class1.2  ...  Class11.4  Class11.5  Class11.6
# 0    100018  0.455420  0.534439  ...   0.001629   0.002941   0.098121
# 1    100037  0.512621  0.473538  ...   0.000157   0.000319   0.017232
# 2    100042  0.705550  0.288080  ...   0.000067   0.000332   0.019833
# 3    100052  0.597933  0.374320  ...   0.001669   0.004281   0.036124
# 4    100056  0.364311  0.624989  ...   0.000188   0.000253   0.006245
# 5    100058  0.254371  0.713031  ...   0.014215   0.011091   0.152236
# 6    100062  0.267081  0.717246  ...   0.008225   0.008682   0.201154
# 7    100065  0.528248  0.430195  ...   0.000354   0.001351   0.028319
# 8    100071  0.059366  0.923067  ...   0.003881   0.001806   0.040480
# 9    100076  0.260207  0.703149  ...   0.005482   0.005184   0.131288
#
# [10 rows x 38 columns]

# %%
df_means.to_csv('Results_final_Resnet50_Xception.csv', index=False)
